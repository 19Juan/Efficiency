# %% [markdown]
# # Eficiencia

# %%
import pandas as pd
df = pd.read_csv('../data/processed/BD.csv', sep=';', encoding='latin1')
df.info()
df.shape
#No se cuenta con valores nulos.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3329 entries, 0 to 3328
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MARCA                        3329 non-null   object
#  1   AGUA EN CRUDOS               3329 non-null   object
#  2   RELACION DE AGUA CRUDOS      3329 non-null   object
#  3   RELACION DE AGUA MEZCLAS     3329 non-null   float64
#  4   VOLUMEN TOTAL DE FILTRACION  3329 non-null   object
#  5   DIFERENCIAL T vapor y mosto  3329 non-null   float64
#  6   Extracto inicio coccion      3329 non-null   float64
#  7   Extracto  fin coccion        3329 non-null   float64
#  8    Rata Evap                   3329 non-null   object
#  9   Tiempo total estres termico  3329 non-null   int64
#  10  Volumen mosto frio           3329 non-null   object
#  11  EO mosto frio                3329 non-null   float64
# ...

# %%
#AHora quiero pasar todas las variables, menos marca, a numericas
df['AGUA EN CRUDOS'] = pd.to_numeric(df['AGUA EN CRUDOS'], errors='coerce')
df['RELACION DE AGUA CRUDOS'] = pd.to_numeric(df['RELACION DE AGUA CRUDOS'], errors='coerce')
df['RELACION DE AGUA MEZCLAS'] = pd.to_numeric(df['RELACION DE AGUA MEZCLAS'], errors='coerce')
df['VOLUMEN TOTAL DE FILTRACION'] = pd.to_numeric(df['VOLUMEN TOTAL DE FILTRACION'], errors='coerce')
df['DIFERENCIAL T vapor y mosto'] = pd.to_numeric(df['DIFERENCIAL T vapor y mosto'], errors='coerce')
df['Extracto inicio coccion'] = pd.to_numeric(df['Extracto inicio coccion'], errors='coerce')
df['Extracto  fin coccion'] = pd.to_numeric(df['Extracto  fin coccion'], errors='coerce')
df[' Rata Evap '] = pd.to_numeric(df[' Rata Evap '], errors='coerce')
df['Tiempo total estres termico'] = pd.to_numeric(df['Tiempo total estres termico'], errors='coerce')
df['Volumen mosto frio'] = pd.to_numeric(df['Volumen mosto frio'], errors='coerce')
df['EO mosto frio'] = pd.to_numeric(df['EO mosto frio'], errors='coerce')
df['pH mosto frio'] = pd.to_numeric(df['pH mosto frio'], errors='coerce')
df['Kg Extracto entrada'] = pd.to_numeric(df['Kg Extracto entrada'], errors='coerce')
df['Eficiencia'] = pd.to_numeric(df['Eficiencia'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3329 entries, 0 to 3328
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MARCA                        3329 non-null   object
#  1   AGUA EN CRUDOS               2422 non-null   float64
#  2   RELACION DE AGUA CRUDOS      2422 non-null   float64
#  3   RELACION DE AGUA MEZCLAS     3329 non-null   float64
#  4   VOLUMEN TOTAL DE FILTRACION  3025 non-null   float64
#  5   DIFERENCIAL T vapor y mosto  3329 non-null   float64
#  6   Extracto inicio coccion      3329 non-null   float64
#  7   Extracto  fin coccion        3329 non-null   float64
#  8    Rata Evap                   3067 non-null   float64
#  9   Tiempo total estres termico  3329 non-null   int64
#  10  Volumen mosto frio           3315 non-null   float64
#  11  EO mosto frio                3329 non-null   float64
# ...

# %%
#Ahora a borrar filas con nulos:
df = df.dropna()
df
# Out:
#              MARCA  AGUA EN CRUDOS  RELACION DE AGUA CRUDOS  \
# 5     ESTANDAR 900           176.4                      2.5
# 6     ESTANDAR 900           176.4                      2.5
# 7     ESTANDAR 900           176.2                      2.5
# 9     ESTANDAR 900           176.4                      2.5
# 10    ESTANDAR 900           176.4                      2.5
# ...            ...             ...                      ...
# 3311   ESTANDAR 18           211.4                      2.8
# 3324   ESTANDAR 18           211.4                      2.8
# 3325   ESTANDAR 18           211.4                      2.9
# 3326   ESTANDAR 18           211.4                      2.9
# 3328   ESTANDAR 18           211.4                      2.8
#
#       RELACION DE AGUA MEZCLAS  VOLUMEN TOTAL DE FILTRACION  \
# 5                          2.0                        945.0
# 6                          2.0                        945.0
# 7                          2.0                        944.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1940 entries, 5 to 3328
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MARCA                        1940 non-null   object
#  1   AGUA EN CRUDOS               1940 non-null   float64
#  2   RELACION DE AGUA CRUDOS      1940 non-null   float64
#  3   RELACION DE AGUA MEZCLAS     1940 non-null   float64
#  4   VOLUMEN TOTAL DE FILTRACION  1940 non-null   float64
#  5   DIFERENCIAL T vapor y mosto  1940 non-null   float64
#  6   Extracto inicio coccion      1940 non-null   float64
#  7   Extracto  fin coccion        1940 non-null   float64
#  8    Rata Evap                   1940 non-null   float64
#  9   Tiempo total estres termico  1940 non-null   int64
#  10  Volumen mosto frio           1940 non-null   float64
#  11  EO mosto frio                1940 non-null   float64
# ...

# %%
#Análisis univariante
#variable categórica
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(1, figsize=(15, 5))

sns.histplot(df['MARCA'], ax=axis).set(ylabel='Frecuencia')
plt.title('Distribución de la variable MARCA')

plt.grid(axis='y')

plt.show()

# %%
df['MARCA'] = pd.factorize(df['MARCA'])[0]

sns.heatmap(df[['MARCA','Kg Extracto entrada',
'RELACION DE AGUA CRUDOS',
'RELACION DE AGUA MEZCLAS',
'VOLUMEN TOTAL DE FILTRACION',
'DIFERENCIAL T vapor y mosto',
'Extracto inicio coccion',
'Extracto  fin coccion',
'EO mosto frio',
'Volumen mosto frio',
'Eficiencia']].corr(), annot=True,fmt='.1f')
plt.title('Correlación entre variables')
plt.tight_layout()
plt.show()

#Ahora quiero guardar la imagen del heat map
plt.savefig('../data/processed/heatmap.png', dpi=300, bbox_inches='tight')

# %%
sns.heatmap(df[[' Rata Evap ',
'EO mosto frio',
'pH mosto frio',
'Kg Extracto entrada',
'Eficiencia']].corr(), annot=True,fmt='.1f')
plt.title('Correlación entre variables')
plt.tight_layout()
plt.show()
